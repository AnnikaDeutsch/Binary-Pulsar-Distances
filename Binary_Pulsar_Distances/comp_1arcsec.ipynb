# %%
import astropy.units as u
from astroquery.gaia import Gaia
from astropy.coordinates import SkyCoord, Angle
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack

import eliminating

# %%
npz = np.load('/home/billee/Binary-Pulsar-Distances/Binary_Pulsar_Distances/cross-matches/matches_10arcsec_11-1_sourceseps.npz', allow_pickle=True)
table = Table(npz['arr_0'])

# %%
lt_1arcsec = Angle(table['source_seps'], unit=u.deg).arcsec <= 1.0

table_1arcsec = table[lt_1arcsec]

# %%
table_1arcsec
# Out:
# <Table length=167>
# Companion Pulsar    Pulsar RA    ... libname_gspphot          dist
#      str12            str16      ...      object            float64
# ---------------- --------------- ... --------------- ----------------------
#     J0024-7204aa     00:24:05.67 ...                  0.0001497802164044604
#      J0024-7204Q   00:24:16.4909 ...                 0.00020433748102279196
#      J0024-7204U   00:24:09.8366 ...                 0.00011908793199581244
#      J0024-7204V     00:24:05.67 ...                 0.00015813960709129226
#       J0337+1715  03:37:43.82589 ...         PHOENIX  8.750602361554736e-06
#       J0348+0432 03:48:43.639000 ...                  6.869018823749552e-06
#      J0514-4002A  05:14:06.69271 ...                 0.00011682181621506537
#       J0534+2200    05:34:31.973 ...           MARCS 2.2726742720782356e-05
#       J0614+2229   06:14:17.0058 ...                 0.00010632612519567557
#       J1012+5307 10:12:33.438448 ...                  4.171814020694746e-06
#              ...             ... ...             ...                    ...
#      J2129+1210E    21:29:58.187 ...                 0.00022095443415936345
#      J2129+1210E    21:29:58.187 ...                 0.00025244873678626064
#      J2129+1210F    21:29:57.178 ...                 0.00015093103815560455
#      J2129+1210G     21:29:57.95 ...           MARCS  0.0002974119890535592
#      J2129+1210H    21:29:58.184 ...                  0.0002483531926616026
#      J2140-2310A  21:40:22.40610 ...                 0.00011160958050724822
#      J2140-2310A  21:40:22.40610 ...                 0.00015839468945811442
#      J2140-2310B        21:40:22 ...                 0.00013384555419486242
#      J2140-2310B        21:40:22 ...                 0.00020110193921676518
#       J2339-0533     23:39:38.74 ...                  2.961637241820589e-05
